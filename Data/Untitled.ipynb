# %%
import pandas as pd

# %%
df = pd.io.parsers.read_csv("jobdescriptions.csv")

# %%
df
# Out:
#                                      Title  \
# 0                         Graphic Designer
# 1                      Software Developers
# 2                         Graphic Designer
# 3                       Software Developer
# 4                Game Developer Specialist
# ...                                    ...
# 3352  Junior Mobile Visual UI/ UX Designer
# 3353               JavaScript Professional
# 3354                        Java Developer
# 3355                      C/ C++ Developer
# 3356                        .NET Developer
#
#                                          JobDescription  \
# 0     The position of Graphic Designer (GD) demands ...
# 1     We are looking for a Programmers with knowledg...
# 2     Ameria CJSC is seeking qualified candidates fo...
# 3     Synergy International Systems, Inc./Armenia se...
# 4     The IT company is looking for high qualified G...
# ...                                                 ...
# ...

# %%
df.
